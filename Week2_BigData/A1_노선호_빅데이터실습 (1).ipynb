# %% [markdown]
# # [실습] 18p

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
np.random.seed(1234)
df = pd.DataFrame(randn(10,2),columns=['A','B'])

# %%
df.head()
# Out:
#           A         B
# 0  0.471435 -1.190976
# 1  1.432707 -0.312652
# 2 -0.720589  0.887163
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685

# %%
df['A']
# Out:
# 0    0.471435
# 1    1.432707
# 2   -0.720589
# 3    0.859588
# 4    0.015696
# 5    1.150036
# 6    0.953324
# 7   -0.334077
# 8    0.405453
# 9    1.321158
# Name: A, dtype: float64

# %%
df[['A']]
# Out:
#           A
# 0  0.471435
# 1  1.432707
# 2 -0.720589
# 3  0.859588
# 4  0.015696
# 5  1.150036
# 6  0.953324
# 7 -0.334077
# 8  0.405453
# 9  1.321158

# %%
df.A
# Out:
# 0    0.471435
# 1    1.432707
# 2   -0.720589
# 3    0.859588
# 4    0.015696
# 5    1.150036
# 6    0.953324
# 7   -0.334077
# 8    0.405453
# 9    1.321158
# Name: A, dtype: float64

# %%
df.loc[3:8]
# Out:
#           A         B
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685
# 5  1.150036  0.991946
# 6  0.953324 -2.021255
# 7 -0.334077  0.002118
# 8  0.405453  0.289092

# %%
df.loc[0:7,['A']]
# Out:
#           A
# 0  0.471435
# 1  1.432707
# 2 -0.720589
# 3  0.859588
# 4  0.015696
# 5  1.150036
# 6  0.953324
# 7 -0.334077

# %%
df.iloc[0:7,[1]]
# Out:
#           B
# 0 -1.190976
# 1 -0.312652
# 2  0.887163
# 3 -0.636524
# 4 -2.242685
# 5  0.991946
# 6 -2.021255

# %%
df.iloc[:,[0]]
# Out:
#           A
# 0  0.471435
# 1  1.432707
# 2 -0.720589
# 3  0.859588
# 4  0.015696
# 5  1.150036
# 6  0.953324
# 7 -0.334077
# 8  0.405453
# 9  1.321158

# %%
df.iloc[3:8]
# Out:
#           A         B
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685
# 5  1.150036  0.991946
# 6  0.953324 -2.021255
# 7 -0.334077  0.002118

# %%
df.loc[0:3,['A']]
# Out:
#           A
# 0  0.471435
# 1  1.432707
# 2 -0.720589
# 3  0.859588

# %%
df.query('A>B')
# Out:
#           A         B
# 0  0.471435 -1.190976
# 1  1.432707 -0.312652
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685
# 5  1.150036  0.991946
# 6  0.953324 -2.021255
# 8  0.405453  0.289092
# 9  1.321158 -1.546906

# %%
df[df.A>df.B]
# Out:
#           A         B
# 0  0.471435 -1.190976
# 1  1.432707 -0.312652
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685
# 5  1.150036  0.991946
# 6  0.953324 -2.021255
# 8  0.405453  0.289092
# 9  1.321158 -1.546906

# %%
df.query('A>0.5 & B<0.0')
# Out:
#           A         B
# 1  1.432707 -0.312652
# 3  0.859588 -0.636524
# 6  0.953324 -2.021255
# 9  1.321158 -1.546906

# %%
df.query('A <0.5 | B<0.5')
# Out:
#           A         B
# 0  0.471435 -1.190976
# 1  1.432707 -0.312652
# 2 -0.720589  0.887163
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685
# 6  0.953324 -2.021255
# 7 -0.334077  0.002118
# 8  0.405453  0.289092
# 9  1.321158 -1.546906

# %% [markdown]
# # [실습]

# %%
np.random.seed(1234)
df = pd.DataFrame(randn(10,4),columns=['A','B','C','D'])

# %%
df.head(12)
# Out:
#           A         B         C         D
# 0  0.471435 -1.190976  1.432707 -0.312652
# 1 -0.720589  0.887163  0.859588 -0.636524
# 2  0.015696 -2.242685  1.150036  0.991946
# 3  0.953324 -2.021255 -0.334077  0.002118
# 4  0.405453  0.289092  1.321158 -1.546906
# 5 -0.202646 -0.655969  0.193421  0.553439
# 6  1.318152 -0.469305  0.675554 -1.817027
# 7 -0.183109  1.058969 -0.397840  0.337438
# 8  1.047579  1.045938  0.863717 -0.122092
# 9  0.124713 -0.322795  0.841675  2.390961

# %%
df['B']
# Out:
# 0   -1.190976
# 1    0.887163
# 2   -2.242685
# 3   -2.021255
# 4    0.289092
# 5   -0.655969
# 6   -0.469305
# 7    1.058969
# 8    1.045938
# 9   -0.322795
# Name: B, dtype: float64

# %%
df[['B','D']]
# Out:
#           B         D
# 0 -1.190976 -0.312652
# 1  0.887163 -0.636524
# 2 -2.242685  0.991946
# 3 -2.021255  0.002118
# 4  0.289092 -1.546906
# 5 -0.655969  0.553439
# 6 -0.469305 -1.817027
# 7  1.058969  0.337438
# 8  1.045938 -0.122092
# 9 -0.322795  2.390961

# %%
df[4:9]
# Out:
#           A         B         C         D
# 4  0.405453  0.289092  1.321158 -1.546906
# 5 -0.202646 -0.655969  0.193421  0.553439
# 6  1.318152 -0.469305  0.675554 -1.817027
# 7 -0.183109  1.058969 -0.397840  0.337438
# 8  1.047579  1.045938  0.863717 -0.122092

# %%
df.loc[2:8,['A','C']]
# Out:
#           A         C
# 2  0.015696  1.150036
# 3  0.953324 -0.334077
# 4  0.405453  1.321158
# 5 -0.202646  0.193421
# 6  1.318152  0.675554
# 7 -0.183109 -0.397840
# 8  1.047579  0.863717

# %%
df.loc[:,['A','C']]
# Out:
#           A         C
# 0  0.471435  1.432707
# 1 -0.720589  0.859588
# 2  0.015696  1.150036
# 3  0.953324 -0.334077
# 4  0.405453  1.321158
# 5 -0.202646  0.193421
# 6  1.318152  0.675554
# 7 -0.183109 -0.397840
# 8  1.047579  0.863717
# 9  0.124713  0.841675

# %%
df.loc[3:8]
# Out:
#           A         B         C         D
# 3  0.953324 -2.021255 -0.334077  0.002118
# 4  0.405453  0.289092  1.321158 -1.546906
# 5 -0.202646 -0.655969  0.193421  0.553439
# 6  1.318152 -0.469305  0.675554 -1.817027
# 7 -0.183109  1.058969 -0.397840  0.337438
# 8  1.047579  1.045938  0.863717 -0.122092

# %%
df.loc[3:4]
# Out:
#           A         B         C         D
# 3  0.953324 -2.021255 -0.334077  0.002118
# 4  0.405453  0.289092  1.321158 -1.546906

# %%
df.iloc[0:7,[0]]
# Out:
#           A
# 0  0.471435
# 1 -0.720589
# 2  0.015696
# 3  0.953324
# 4  0.405453
# 5 -0.202646
# 6  1.318152

# %%
df.iloc[:,[0]]
# Out:
#           A
# 0  0.471435
# 1 -0.720589
# 2  0.015696
# 3  0.953324
# 4  0.405453
# 5 -0.202646
# 6  1.318152
# 7 -0.183109
# 8  1.047579
# 9  0.124713

# %%
df.iloc[2:7]
# Out:
#           A         B         C         D
# 2  0.015696 -2.242685  1.150036  0.991946
# 3  0.953324 -2.021255 -0.334077  0.002118
# 4  0.405453  0.289092  1.321158 -1.546906
# 5 -0.202646 -0.655969  0.193421  0.553439
# 6  1.318152 -0.469305  0.675554 -1.817027

# %%
df.iloc[5:6]
# Out:
#           A         B         C         D
# 5 -0.202646 -0.655969  0.193421  0.553439

# %%
df.query('D>0.5')
# Out:
#           A         B         C         D
# 2  0.015696 -2.242685  1.150036  0.991946
# 5 -0.202646 -0.655969  0.193421  0.553439
# 9  0.124713 -0.322795  0.841675  2.390961

# %%
df.query('D<0.0')
# Out:
#           A         B         C         D
# 0  0.471435 -1.190976  1.432707 -0.312652
# 1 -0.720589  0.887163  0.859588 -0.636524
# 4  0.405453  0.289092  1.321158 -1.546906
# 6  1.318152 -0.469305  0.675554 -1.817027
# 8  1.047579  1.045938  0.863717 -0.122092

# %%
df.query('A>0.5')
# Out:
#           A         B         C         D
# 3  0.953324 -2.021255 -0.334077  0.002118
# 6  1.318152 -0.469305  0.675554 -1.817027
# 8  1.047579  1.045938  0.863717 -0.122092

# %%
df.query('D<0.0')
# Out:
#           A         B         C         D
# 0  0.471435 -1.190976  1.432707 -0.312652
# 1 -0.720589  0.887163  0.859588 -0.636524
# 4  0.405453  0.289092  1.321158 -1.546906
# 6  1.318152 -0.469305  0.675554 -1.817027
# 8  1.047579  1.045938  0.863717 -0.122092

# %%
df = pd.DataFrame({'ABC':['A','B','C','A'],'abc':['a','b','c','d'],'group1':['G1','G2','G3','G4'],'value1':[11,13,12,14],

                'val_1':[0.231,0.197,0.213,0.199]})

# %%
df.head()
# Out:
#   ABC abc group1  value1  val_1
# 0   A   a     G1      11  0.231
# 1   B   b     G2      13  0.197
# 2   C   c     G3      12  0.213
# 3   A   d     G4      14  0.199

# %%
df.filter(items=['group1','value1'])
# Out:
#   group1  value1
# 0     G1      11
# 1     G2      13
# 2     G3      12
# 3     G4      14

# %%
df.filter(regex='1',axis = 1)
# Out:
#   group1  value1  val_1
# 0     G1      11  0.231
# 1     G2      13  0.197
# 2     G3      12  0.213
# 3     G4      14  0.199

# %%
df.filter(regex='1$', axis =1)
# Out:
#   group1  value1  val_1
# 0     G1      11  0.231
# 1     G2      13  0.197
# 2     G3      12  0.213
# 3     G4      14  0.199

# %%
df.filter(like='a',axis=1)
# Out:
#   abc  value1  val_1
# 0   a      11  0.231
# 1   b      13  0.197
# 2   c      12  0.213
# 3   d      14  0.199

# %%
df.filter(regex='[Aa]',axis =1 )
# Out:
#   ABC abc  value1  val_1
# 0   A   a      11  0.231
# 1   B   b      13  0.197
# 2   C   c      12  0.213
# 3   A   d      14  0.199

# %%
df.mask(df.value1>12)
# Out:
#    ABC  abc group1  value1  val_1
# 0    A    a     G1    11.0  0.231
# 1  NaN  NaN    NaN     NaN    NaN
# 2    C    c     G3    12.0  0.213
# 3  NaN  NaN    NaN     NaN    NaN

# %%
df.mask(df.abc=='a')
# Out:
#    ABC  abc group1  value1  val_1
# 0  NaN  NaN    NaN     NaN    NaN
# 1    B    b     G2    13.0  0.197
# 2    C    c     G3    12.0  0.213
# 3    A    d     G4    14.0  0.199

# %%
df.mask(cond= df.value1>12, other=999)
# Out:
#    ABC  abc group1  value1    val_1
# 0    A    a     G1      11    0.231
# 1  999  999    999     999  999.000
# 2    C    c     G3      12    0.213
# 3  999  999    999     999  999.000

# %%
df1 = pd.DataFrame({'A':['A0','A1','A2','A3'],'B':['B0','B1','B2','B3'],'C':['C0','C1','C2','C3'],'D':['D0','D1','D2','D3']},index =[0,1,2,3])
df2 = pd.DataFrame({'A':['A0','A1','A2','A3'],'B':['B0','B1','B2','B3'],'C':['C0','C1','C2','C3'],'D':['D0','D1','D2','D3']},index =[4,5,6,7])
df3 = pd.DataFrame({'A':['A0','A1','A2','A3'],'B':['B0','B1','B2','B3'],'C':['C0','C1','C2','C3'],'D':['D0','D1','D2','D3']},index =[8,9,10,11])

# %%
result= pd.concat([df1,df2,df3])

# %%
result
# Out:
#      A   B   C   D
# 0   A0  B0  C0  D0
# 1   A1  B1  C1  D1
# 2   A2  B2  C2  D2
# 3   A3  B3  C3  D3
# 4   A0  B0  C0  D0
# 5   A1  B1  C1  D1
# 6   A2  B2  C2  D2
# 7   A3  B3  C3  D3
# 8   A0  B0  C0  D0
# 9   A1  B1  C1  D1
# 10  A2  B2  C2  D2
# 11  A3  B3  C3  D3

# %%
result = pd.concat([df1,df2,df3], axis = 1)

# %%
result
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A0   B0   C0   D0  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A1   B1   C1   D1  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A2   B2   C2   D2  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A3   B3   C3   D3  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A0   B0   C0   D0
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A1   B1   C1   D1
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A2   B2   C2   D2
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A3   B3   C3   D3

# %%
result= pd.concat([df1,df2,df3],axis = 1, ignore_index=True)

# %%
result.columns = ["col_"+str(i) for i in range(12)]

# %%
result
# Out:
#    col_0 col_1 col_2 col_3 col_4 col_5 col_6 col_7 col_8 col_9 col_10 col_11
# 0     A0    B0    C0    D0   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 1     A1    B1    C1    D1   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 2     A2    B2    C2    D2   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 3     A3    B3    C3    D3   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 4    NaN   NaN   NaN   NaN    A0    B0    C0    D0   NaN   NaN    NaN    NaN
# 5    NaN   NaN   NaN   NaN    A1    B1    C1    D1   NaN   NaN    NaN    NaN
# 6    NaN   NaN   NaN   NaN    A2    B2    C2    D2   NaN   NaN    NaN    NaN
# 7    NaN   NaN   NaN   NaN    A3    B3    C3    D3   NaN   NaN    NaN    NaN
# 8    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    A0    B0     C0     D0
# 9    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    A1    B1     C1     D1
# 10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    A2    B2     C2     D2
# ...

# %%
left = pd.DataFrame({'key1':['K0','K1','K2','K3'],'key2':['K0','K1','K0','K1'],'A':['A0','A1','A2','A3'],'B':['B0','B1','B2','B3']})
right = pd.DataFrame({'key1':['K0','K1','K2','K3'],'key2':['K0','K0','K0','K0'],'C':['C0','C1','C2','C3'],'D':['D0','D1','D2','D3']})

# %%
left.head()
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K1   K1  A1  B1
# 2   K2   K0  A2  B2
# 3   K3   K1  A3  B3

# %%
right.head()
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K2   K0  C2  D2
# 3   K3   K0  C3  D3

# %%
result =pd.merge(left,right,on=['key1','key2'])

# %%
result
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K2   K0  A2  B2  C2  D2

# %%
result =pd.merge(left,right, on =['key1','key2'],how='left')

# %%
result
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K1   K1  A1  B1  NaN  NaN
# 2   K2   K0  A2  B2   C2   D2
# 3   K3   K1  A3  B3  NaN  NaN

# %%
result = pd.merge(left,right, on =['key1','key2'],how= 'right')

# %%
result
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K2   K0   A2   B2  C2  D2
# 2   K1   K0  NaN  NaN  C1  D1
# 3   K3   K0  NaN  NaN  C3  D3

# %%
result = pd.merge(left,right, on =['key1','key2'], how='outer', indicator=True)

# %%
result
# Out:
#   key1 key2    A    B    C    D      _merge
# 0   K0   K0   A0   B0   C0   D0        both
# 1   K1   K1   A1   B1  NaN  NaN   left_only
# 2   K2   K0   A2   B2   C2   D2        both
# 3   K3   K1   A3   B3  NaN  NaN   left_only
# 4   K1   K0  NaN  NaN   C1   D1  right_only
# 5   K3   K0  NaN  NaN   C3   D3  right_only

# %%
left = pd.DataFrame({'key1':[1,2,3,4],'A':['A0','A1','A2','A3'],'B':['B0','B1','B2','B3']})
right = pd.DataFrame({'C':['C1','C2','C5'],'D':['D1','D2','D5']})

# %%
left.head()
# Out:
#    key1   A   B
# 0     1  A0  B0
# 1     2  A1  B1
# 2     3  A2  B2
# 3     4  A3  B3

# %%
right.head()
# Out:
#     C   D
# 0  C1  D1
# 1  C2  D2
# 2  C5  D5

# %%
result = left.join(right)

# %%
result
# Out:
#    key1   A   B    C    D
# 0     1  A0  B0   C1   D1
# 1     2  A1  B1   C2   D2
# 2     3  A2  B2   C5   D5
# 3     4  A3  B3  NaN  NaN

# %%
result = left.join(right,how='right')

# %%
result
# Out:
#    key1   A   B   C   D
# 0     1  A0  B0  C1  D1
# 1     2  A1  B1  C2  D2
# 2     3  A2  B2  C5  D5

# %%
result = left.join(right , how='inner')
result
# Out:
#    key1   A   B   C   D
# 0     1  A0  B0  C1  D1
# 1     2  A1  B1  C2  D2
# 2     3  A2  B2  C5  D5

# %%
result = left.join(right , how='outer')
result
# Out:
#    key1   A   B    C    D
# 0     1  A0  B0   C1   D1
# 1     2  A1  B1   C2   D2
# 2     3  A2  B2   C5   D5
# 3     4  A3  B3  NaN  NaN

# %%
result = left.join(right,on='key1')
result
# Out:
#    key1   A   B    C    D
# 0     1  A0  B0   C2   D2
# 1     2  A1  B1   C5   D5
# 2     3  A2  B2  NaN  NaN
# 3     4  A3  B3  NaN  NaN

# %%
result = left.join(right,on='key1')
result
# Out:
#    key1   A   B    C    D
# 0     1  A0  B0   C2   D2
# 1     2  A1  B1   C5   D5
# 2     3  A2  B2  NaN  NaN
# 3     4  A3  B3  NaN  NaN

# %%
result2 = pd.merge(left,right,left_on = 'key1',right_index = True, how='left')

# %%
result2
# Out:
#    key1   A   B    C    D
# 0     1  A0  B0   C2   D2
# 1     2  A1  B1   C5   D5
# 2     3  A2  B2  NaN  NaN
# 3     4  A3  B3  NaN  NaN

# %%
left = pd.read_csv('/home/piai/Downloads/data_handling/FITNESS_1.csv',engine='python',encoding='CP949')

# %%
right= pd.read_csv('/home/piai/Downloads/data_handling/FITNESS_2.csv',engine='python',encoding='CP949')

# %%
left.head()
# Out:
#      NAME GENDER  AGE AGEGROUP  WEIGHT
# 0   Donna     여성   42      40대   68.15
# 1  Gracie     여성   38      30대   81.87
# 2  Luanne     여성   43      40대   85.84
# 3    Mimi     여성   50      50대   70.87
# 4   Chris     남성   49      40대   81.42

# %%
right.head()
# Out:
#      NAME GENDER  AGE     OXY  RUNTIME  RUNPULSE  RSTPULSE  MAXPULSE
# 0   Donna     여성   42  59.571     8.17       166        40       172
# 1  Gracie     여성   38  60.055     8.63       170        48       186
# 2  Luanne     여성   43  54.297     8.65       156        45       168
# 3    Mimi     여성   50  54.625     8.92       146        48       155
# 4   Chris     남성   49  49.156     8.95       180        44       185

# %%
result=pd.merge(left,right,on=['NAME','GENDER'])
result
# Out:
#         NAME GENDER  AGE_x AGEGROUP  WEIGHT  AGE_y     OXY  RUNTIME  RUNPULSE  \
# 0      Donna     여성     42      40대   68.15     42  59.571     8.17       166
# 1     Gracie     여성     38      30대   81.87     38  60.055     8.63       170
# 2     Luanne     여성     43      40대   85.84     43  54.297     8.65       156
# 3       Mimi     여성     50      50대   70.87     50  54.625     8.92       146
# 4      Chris     남성     49      40대   81.42     49  49.156     8.95       180
# 5      Allen     남성     38      30대   89.02     38  49.874     9.22       178
# 6      Nancy     여성     49      40대   76.32     49  48.673     9.40       186
# 7      Patty     여성     52      50대   76.32     52  45.441     9.63       164
# 8    Suzanne     여성     57      50대   59.08     57  50.545     9.93       148
# 9     Teresa     여성     51      50대   77.91     51  46.672    10.00       162
# 10       Bob     남성     39      30대   75.07     39  45.313    10.07       185
# ...

# %%
df =pd.DataFrame({'index':[1,1,1,2,2,2],
                 'column':['col_1','col_2','col_3','col_1','col_2','col_3'],
                 'value_1':[1,2,3,4,5,6],
                 'value_2':['x','y','z','q','w','t'] })

# %%
df.head()
# Out:
#    index column  value_1 value_2
# 0      1  col_1        1       x
# 1      1  col_2        2       y
# 2      1  col_3        3       z
# 3      2  col_1        4       q
# 4      2  col_2        5       w

# %%
df.pivot(index= 'index', columns='column',values = 'value_1')
# Out:
# column  col_1  col_2  col_3
# index
# 1           1      2      3
# 2           4      5      6

# %%
df.pivot(index='index',columns='column')['value_1']
# Out:
# column  col_1  col_2  col_3
# index
# 1           1      2      3
# 2           4      5      6

# %%
df.pivot(index='index',columns='column',values=['value_1','value_2'])
# Out:
#        value_1             value_2
# column   col_1 col_2 col_3   col_1 col_2 col_3
# index
# 1            1     2     3       x     y     z
# 2            4     5     6       q     w     t

# %%
x=df.pivot(index='index',columns='column')

# %%
df.pivot(columns='column',values='value_1')
# Out:
# column  col_1  col_2  col_3
# 0         1.0    NaN    NaN
# 1         NaN    2.0    NaN
# 2         NaN    NaN    3.0
# 3         4.0    NaN    NaN
# 4         NaN    5.0    NaN
# 5         NaN    NaN    6.0

# %%
df= pd.read_csv("/home/piai/Downloads/data_handling/FITNESS.csv",engine='python',encoding='CP949')
df.head()
# Out:
#      NAME GENDER  AGE  AGEGROUP  WEIGHT     OXY  RUNTIME  RUNPULSE  RSTPULSE  \
# 0   Donna      F   42        40   68.15  59.571     8.17       166        40
# 1  Gracie          38        30   81.87  60.055     8.63       170        48
# 2  Luanne      F   43        40   85.84  54.297     8.65       156        45
# 3    Mimi      F   50        50   70.87  54.625     8.92       146        48
# 4   Chris      M   49        40   70.00  49.156     8.95       180        44
#
#    MAXPULSE
# 0       172
# 1       186
# 2       168
# 3       155
# 4       185

# %%
df=df.replace('F','여성')
df=df.replace('M','남성')
df=df.replace(' ','여성')

df.head()
# Out:
#      NAME GENDER  AGE  AGEGROUP  WEIGHT     OXY  RUNTIME  RUNPULSE  RSTPULSE  \
# 0   Donna     여성   42        40   68.15  59.571     8.17       166        40
# 1  Gracie     여성   38        30   81.87  60.055     8.63       170        48
# 2  Luanne     여성   43        40   85.84  54.297     8.65       156        45
# 3    Mimi     여성   50        50   70.87  54.625     8.92       146        48
# 4   Chris     남성   49        40   70.00  49.156     8.95       180        44
#
#    MAXPULSE
# 0       172
# 1       186
# 2       168
# 3       155
# 4       185

# %%
df= df.groupby(['GENDER','AGEGROUP'],as_index=False)['WEIGHT'].agg('mean')

# %%
df.pivot('GENDER','AGEGROUP','WEIGHT')
# Out:
# AGEGROUP      30        40         50
# GENDER
# 남성        82.758  79.34200  79.426000
# 여성        78.925  72.94375  70.856667

# %%
df.pivot(index='AGEGROUP',columns='GENDER',values='WEIGHT')
# Out:
# GENDER        남성         여성
# AGEGROUP
# 30        82.758  78.925000
# 40        79.342  72.943750
# 50        79.426  70.856667

# %%
df= pd.DataFrame({'index':[1,2,3],'alpha':['A','B','C'],'values':[11,22,33],'xyz':['x','y','z']})
df
# Out:
#    index alpha  values xyz
# 0      1     A      11   x
# 1      2     B      22   y
# 2      3     C      33   z

# %%
df_stack=df.stack()

# %%
df_stack
# Out:
# 0  index      1
#    alpha      A
#    values    11
#    xyz        x
# 1  index      2
#    alpha      B
#    values    22
#    xyz        y
# 2  index      3
#    alpha      C
#    values    33
#    xyz        z
# dtype: object

# %%
print("stack 데이터 크기:", df_stack.shape)
# Out:
# stack 데이터 크기: (12,)

# %%
df_unstack= df_stack.unstack()
df_unstack
# Out:
#   index alpha values xyz
# 0     1     A     11   x
# 1     2     B     22   y
# 2     3     C     33   z

# %%
df=pd.DataFrame({'factor1':['A','A','A','A','A','B','B','B','B'],'factor2':['a','b','c','a','b','a','b','c','c'],'value':[11,13,12,12,14,12,13,11,12]})
df
# Out:
#   factor1 factor2  value
# 0       A       a     11
# 1       A       b     13
# 2       A       c     12
# 3       A       a     12
# 4       A       b     14
# 5       B       a     12
# 6       B       b     13
# 7       B       c     11
# 8       B       c     12

# %%
pd.crosstab(df.factor1,df.factor2)
# Out:
# factor2  a  b  c
# factor1
# A        2  2  1
# B        1  1  2

# %%
pd.crosstab(df.factor1,df.factor2,rownames=['Fact1'],colnames=['Fact2'],margins=True)
# Out:
# Fact2  a  b  c  All
# Fact1
# A      2  2  1    5
# B      1  1  2    4
# All    3  3  3    9

# %%
pd.crosstab(df.factor1,[df.factor2,df.value])
# Out:
# factor2  a     b     c
# value   11 12 13 14 11 12
# factor1
# A        1  1  1  1  0  1
# B        0  1  1  0  1  1

# %%
pd.crosstab(df.factor1,df.factor2,margins=True,normalize=True)
# Out:
# factor2         a         b         c       All
# factor1
# A        0.222222  0.222222  0.111111  0.555556
# B        0.111111  0.111111  0.222222  0.444444
# All      0.333333  0.333333  0.333333  1.000000

# %%
pop_seoul=pd.read_csv("/home/piai/Downloads/data_handling/서울인구통계.txt",sep='\t',engine='python',thousands=',',encoding='utf-8')

# %%
pop_seoul.head()
# Out:
#          기간  자치구       세대        인구     인구.1     인구.2     인구.3     인구.4  \
# 0        기간  자치구       세대        합계       합계       합계      한국인      한국인
# 1        기간  자치구       세대         계       남자       여자        계       남자
# 2  2020.1/4   합계  4354006  10013781  4874995  5138786  9733655  4742217
# 3  2020.1/4  종로구    74151    161984    78271    83713   151217    73704
# 4  2020.1/4   중구    63045    136469    66769    69700   126175    61839
#
#       인구.5    인구.6    인구.7    인구.8  세대당인구  65세이상고령자
# 0      한국인   등록외국인   등록외국인   등록외국인  세대당인구  65세이상고령자
# 1       여자       계      남자      여자  세대당인구  65세이상고령자
# 2  4991438  280126  132778  147348   2.24   1518239
# 3    77513   10767    4567    6200   2.04     28073
# 4    64336   10294    4930    5364      2     23794

# %%
pop1 = pop_seoul[['자치구','인구','인구.3','인구.6','65세이상고령자']]
pop_seoul=pop1.drop([0,1])
pop_seoul.head()
# Out:
#    자치구        인구     인구.3    인구.6 65세이상고령자
# 2   합계  10013781  9733655  280126  1518239
# 3  종로구    161984   151217   10767    28073
# 4   중구    136469   126175   10294    23794
# 5  용산구    246165   229579   16586    39439
# 6  성동구    307193   299042    8151    44728

# %%
pop_seoul.rename(columns={pop_seoul.columns[0]:'구별',
                         pop_seoul.columns[1]:'인구수',
                         pop_seoul.columns[2]:'한국인',
                          pop_seoul.columns[3]:'외국인',
                          pop_seoul.columns[4]:'고령자',},inplace=True)
pop_seoul.head()
# Out:
#     구별       인구수      한국인     외국인      고령자
# 2   합계  10013781  9733655  280126  1518239
# 3  종로구    161984   151217   10767    28073
# 4   중구    136469   126175   10294    23794
# 5  용산구    246165   229579   16586    39439
# 6  성동구    307193   299042    8151    44728

# %%
cctv_seoul=pd.read_excel('/home/piai/Downloads/data_handling/서울시CCTV.xlsx')

# %%
cctv_seoul.head()
# Out:
#      기관명    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강 동 구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강 북 구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강 서 구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관 악 구  3985     430.0   56.0  419.0    487    609    619    694    671

# %%
cctv_seoul.rename(columns={cctv_seoul.columns[0]:'구별'},inplace=True)
cctv_seoul.rename(columns={cctv_seoul.columns[1]:'cctv수'},inplace=True)
cctv_seoul.head()
# Out:
#       구별  cctv수  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구   5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강 동 구   1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강 북 구   1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강 서 구   1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관 악 구   3985     430.0   56.0  419.0    487    609    619    694    671

# %%
cctv_seoul.sort_values(by='cctv수',ascending=True).head(10)
# Out:
#          구별  cctv수  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 9     도 봉 구    858     197.0   66.0    8.0    185     59    155    117     71
# 24    중 랑 구   1068       NaN    NaN    NaN    770    102    121     66      9
# 2     강 북 구   1265     243.0   88.0  141.0     74    145    254      1    319
# 22    종 로 구   1471       8.0    7.0  599.0    132    195    148    281    101
# 23  중     구   1544      25.0  165.0  114.0     80    245    270    317    328
# 5     광 진 구   1581     470.0   42.0   83.0     87     64     21    468    346
# 17    송 파 구   1586     600.0   99.0   88.0     21    166    100    116    396
# 3     강 서 구   1617     219.0  155.0  118.0    230    187    190    264    254
# 7     금 천 구   1634      27.0   17.0  242.0    101    382    136    199    530
# 11    동 작 구   1780     238.0   93.0   29.0    503    130    254    278    255

# %%
cctv_seoul.sort_values(by='cctv수',ascending=False).head(10)
# Out:
#        구별  cctv수  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0   강 남 구   5221    1944.0  195.0  316.0    430    546    765    577    448
# 4   관 악 구   3985     430.0   56.0  419.0    487    609    619    694    671
# 6   구 로 구   3227     852.0  219.0  349.0    187    268    326    540    486
# 16  성 북 구   3003     779.0   84.0  304.0    241    279    388    285    643
# 21  은 평 구   2962    1365.0   83.0   99.0    343    180    296    229    367
# 14  서 초 구   2835    1172.0   91.0  228.0    134    215    352    247    396
# 18  양 천 구   2775     772.0  161.0  185.0    169    172    349    137    830
# 15  성 동 구   2679     665.0  109.0  118.0    101    258    201    933    294
# 19   영등포구   2495     132.0  121.0  206.0    217    366    289    371    793
# 13   서대문구   2121     565.0  233.0  214.0    114    109    277    415    194

# %%
cctv_seoul.isnull().sum()
# Out:
# 구별          0
# cctv수       0
# 2011년 이전    2
# 2012년       2
# 2013년       2
# 2014년       0
# 2015년       0
# 2016년       0
# 2017년       0
# 2018년       0
# dtype: int64

# %%
cctv_seoul.loc[cctv_seoul.isnull()['2011년 이전']]
# Out:
#        구별  cctv수  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 10   동대문구   2003       NaN    NaN    NaN   1326    111    233    136    197
# 24  중 랑 구   1068       NaN    NaN    NaN    770    102    121     66      9

# %%
cctv_seoul['최근증가율']=(cctv_seoul['2018년']+cctv_seoul['2017년']+cctv_seoul['2016년'])/(cctv_seoul['cctv수']-(cctv_seoul['2018년']+cctv_seoul['2017년']+cctv_seoul['2016년']))*100

# %%
cctv_seoul.sort_values(by='최근증가율',ascending=False).head(5)
# Out:
#          구별  cctv수  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 23  중     구   1544      25.0  165.0  114.0     80    245    270    317    328
# 19     영등포구   2495     132.0  121.0  206.0    217    366    289    371    793
# 15    성 동 구   2679     665.0  109.0  118.0    101    258    201    933    294
# 7     금 천 구   1634      27.0   17.0  242.0    101    382    136    199    530
# 5     광 진 구   1581     470.0   42.0   83.0     87     64     21    468    346
#
#          최근증가율
# 23  145.468998
# 19  139.443378
# 15  114.148681
# 7   112.483745
# 5   111.930295

# %%
pop_seoul.head()
# Out:
#     구별       인구수      한국인     외국인      고령자
# 2   합계  10013781  9733655  280126  1518239
# 3  종로구    161984   151217   10767    28073
# 4   중구    136469   126175   10294    23794
# 5  용산구    246165   229579   16586    39439
# 6  성동구    307193   299042    8151    44728

# %%
pop_seoul.drop([2],inplace=True)

# %%
pop_seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자
# 3  종로구  161984  151217  10767  28073
# 4   중구  136469  126175  10294  23794
# 5  용산구  246165  229579  16586  39439
# 6  성동구  307193  299042   8151  44728
# 7  광진구  365990  350417  15573  48989

# %%
pop_seoul.dtypes
pop_seoul=pop_seoul.astype({"인구수":"int","한국인":"int","외국인":"int","고령자":"int"})

# %%
pop_seoul['외국인 비율']=pop_seoul['외국인']/pop_seoul['인구수']*100
pop_seoul['고령자 비율']=pop_seoul['고령자']/pop_seoul['인구수']*100
pop_seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자    외국인 비율     고령자 비율
# 3  종로구  161984  151217  10767  28073  6.646953  17.330724
# 4   중구  136469  126175  10294  23794  7.543105  17.435462
# 5  용산구  246165  229579  16586  39439  6.737757  16.021368
# 6  성동구  307193  299042   8151  44728  2.653381  14.560228
# 7  광진구  365990  350417  15573  48989  4.255034  13.385338

# %%
pop_seoul.sort_values(by='외국인 비율',ascending=False).head()
# Out:
#       구별     인구수     한국인    외국인    고령자    외국인 비율     고령자 비율
# 21  영등포구  404766  371903  32863  59373  8.119012  14.668475
# 4     중구  136469  126175  10294  23794  7.543105  17.435462
# 20   금천구  251370  232583  18787  38508  7.473843  15.319251
# 19   구로구  438308  405837  32471  67432  7.408261  15.384615
# 5    용산구  246165  229579  16586  39439  6.737757  16.021368

# %%
pop_seoul.sort_values(by='고령자 비율',ascending= False).head()
# Out:
#      구별     인구수     한국인    외국인    고령자    외국인 비율     고령자 비율
# 11  강북구  316750  312985   3765  61660  1.188635  19.466456
# 12  도봉구  333495  331238   2257  60023  0.676772  17.998171
# 4    중구  136469  126175  10294  23794  7.543105  17.435462
# 3   종로구  161984  151217  10767  28073  6.646953  17.330724
# 14  은평구  482509  478019   4490  82245  0.930553  17.045278

# %%
cctv_seoul['구별']=['강남구','강동구','강북구','강서구','관악구','광진구','구로구','금천구','노원구','도봉구','동대문구','동작구','마포구','서대문구','서초구','성동구','성북구','송파구','양천구','영등포구','용산구','은평구','종로구','중구','중랑구']

# %%
result=pd.merge(cctv_seoul,pop_seoul,on='구별')

# %%
result
# Out:
#       구별  cctv수  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    강남구   5221    1944.0  195.0  316.0    430    546    765    577    448
# 1    강동구   1879     303.0  387.0  134.0     59    144    194    273    385
# 2    강북구   1265     243.0   88.0  141.0     74    145    254      1    319
# 3    강서구   1617     219.0  155.0  118.0    230    187    190    264    254
# 4    관악구   3985     430.0   56.0  419.0    487    609    619    694    671
# 5    광진구   1581     470.0   42.0   83.0     87     64     21    468    346
# 6    구로구   3227     852.0  219.0  349.0    187    268    326    540    486
# 7    금천구   1634      27.0   17.0  242.0    101    382    136    199    530
# 8    노원구   1906     481.0  117.0  203.0     80    461    298    110    156
# 9    도봉구    858     197.0   66.0    8.0    185     59    155    117     71
# 10  동대문구   2003       NaN    NaN    NaN   1326    111    233    136    197
# ...
