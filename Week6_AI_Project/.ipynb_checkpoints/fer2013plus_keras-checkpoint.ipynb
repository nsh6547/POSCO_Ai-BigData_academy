# %%
#!/usr/bin/python
import tensorflow as tf
 
 
 
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)

import keras
import cv2
import numpy as np
import os
import math

#------------------------------------------------------------------------------
# read all dataset for training
#------------------------------------------------------------------------------
traindir = '/home/piai/Desktop/ferplus/FER2013Train/'
d_ = {}
maxnum = 0
for i in range(8):
    fname = '/home/piai/Desktop/ferplus/ferplus_keras_labe/train-ori-c%d.txt' % (i)
    f = open(fname)
    alllines = f.readlines()
    f.close()
    if maxnum < len(alllines):
        maxnum = len(alllines)
    ##
    d_[i] = alllines
##
##
x_train = np.zeros((maxnum*8, 64, 64, 1), dtype='f')
x_p = np.zeros((maxnum*8, 64, 64, 1), dtype='f')
y_p = np.zeros((maxnum*8), dtype=np.uint8)

idxout = 0
for i in range(8):
    data = d_[i]
    num = 0
    idx = 0    
    while num < maxnum:
        sp = (data[idx]).split(" ")
        y_p[idxout ] = int(sp[1])
        img = cv2.imread(os.path.join(traindir, sp[0]), cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (64,64))
        x_p[idxout, :, :, 0] = img
        ###
        idxout = idxout + 1
        idx = idx + 1
        if idx >= len(data):
            idx = 0
        num = num + 1
    ###
###

randomid = np.random.permutation(x_p.shape[0])
y_p = keras.utils.to_categorical(y_p, num_classes=8)
y_train = np.zeros(y_p.shape, dtype=np.uint8)
for i in range(x_p.shape[0]):
    x_train[i, :, :, :] = x_p[randomid[i], :, :, :].copy()
    y_train[i] = y_p[randomid[i]]
x_p = 0
#------------------------------------------------------------------------------
#------------------------------------------------------------------------------

#------------------------------------------------------------------------------
# read all dataset for validation
#------------------------------------------------------------------------------
valdir = '/home/piai/Desktop/ferplus/FER2013Valid/'
f = open('/home/piai/Desktop/ferplus/ferplus_keras_labe/validation.txt')
alllines = f.readlines()
f.close()

x_val = np.zeros((len(alllines), 64, 64, 1), dtype='f')
y_p = np.zeros((len(alllines)), dtype=np.uint8)

idx = 0
for line in alllines:
    sp = line.split(" ")
    y_p[idx] = int(sp[1])
    img = cv2.imread(os.path.join(valdir, sp[0]), cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (64,64))
    x_val[idx, :, :, 0] = img
    idx = idx + 1
###

y_val = keras.utils.to_categorical(y_p, num_classes=8)
#------------------------------------------------------------------------------

#------------------------------------------------------------------------------
# Model defenition
#------------------------------------------------------------------------------
from keras.preprocessing.image import ImageDataGenerator

### data augmentation
datagen = ImageDataGenerator(featurewise_center=True, 
                             featurewise_std_normalization=True, \
                             width_shift_range=0.08, \
                             height_shift_range=0.08, \
                             zoom_range=0.05, \
                             rotation_range=20, \
                             shear_range=0.05, \
                             horizontal_flip=True)

### model description
vgg13 = keras.models.Sequential()

vgg13.add(keras.layers.Conv2D(64, (3, 3), activation='relu', 
                              input_shape=(64,64,1), padding='same'))
vgg13.add(keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
vgg13.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))
vgg13.add(keras.layers.Dropout(0.25))

vgg13.add(keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
vgg13.add(keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
vgg13.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))
vgg13.add(keras.layers.Dropout(0.25))

vgg13.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
vgg13.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
vgg13.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
vgg13.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))
vgg13.add(keras.layers.Dropout(0.25))

vgg13.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
vgg13.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
vgg13.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
vgg13.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))
vgg13.add(keras.layers.Dropout(0.25))

vgg13.add(keras.layers.Flatten())
vgg13.add(keras.layers.Dense(1024, activation='relu'))
vgg13.add(keras.layers.Dropout(0.5))

vgg13.add(keras.layers.Dense(1024, activation='relu'))
vgg13.add(keras.layers.Dropout(0.5))

vgg13.add(keras.layers.Dense(8, activation='softmax'))
#------------------------------------------------------------------------------
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
x_train.shape
# Out:
# (73144, 64, 64, 1)

# %%
#------------------------------------------------------------------------------
# Training Process
#------------------------------------------------------------------------------

def steplr(epoch):
    lr = 0.025
    max_epochs=100.0
    lr = lr * (1.0 - epoch/max_epochs)
    return lr

sgd = keras.optimizers.SGD(lr=0.025, decay=0.0005, momentum=0.9, nesterov=True)
vgg13.compile(loss='categorical_crossentropy', optimizer=sgd,  
              metrics=['accuracy'])

datagen.fit(x_train)

vgg13.fit_generator(datagen.flow(x_train, y_train, batch_size=128), 
                    steps_per_epoch=x_train.shape[0]/128, 
                    epochs=100, 
                    validation_data=datagen.flow(x_val, y_val, batch_size=128),
                    validation_steps=x_val.shape[0]/128,
                    callbacks=[
                        keras.callbacks.LearningRateScheduler(steplr, verbose=1),
                        keras.callbacks.ModelCheckpoint('vgg13-baseline.h5', 
                            monitor='val_acc', 
                            verbose=1,
                            save_best_only=True)
                        ]
                    )
#------------------------------------------------------------------------------
# Out:
# WARNING:tensorflow:From <ipython-input-3-8cf983522d7e>:27: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.025.
# Epoch 1/100
# 572/571 [==============================] - ETA: 0s - loss: 2.0101 - accuracy: 0.1932WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 107s 187ms/step - loss: 2.0101 - accuracy: 0.1932 - val_loss: 1.9087 - val_accuracy: 0.2355 - lr: 0.0250
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.02475.
# Epoch 2/100
# 571/571 [============================>.] - ETA: 0s - loss: 1.7980 - accuracy: 0.3108WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 43s 75ms/step - loss: 1.7978 - accuracy: 0.3109 - val_loss: 1.6902 - val_accuracy: 0.3376 - lr: 0.0247
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0245.
# Epoch 3/100
# 571/571 [============================>.] - ETA: 0s - loss: 1.4118 - accuracy: 0.4761WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 1.4117 - accuracy: 0.4761 - val_loss: 1.5007 - val_accuracy: 0.4378 - lr: 0.0245
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.02425.
# Epoch 4/100
# 571/571 [============================>.] - ETA: 0s - loss: 1.0485 - accuracy: 0.6132WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 1.0484 - accuracy: 0.6132 - val_loss: 1.0557 - val_accuracy: 0.6036 - lr: 0.0243
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.024.
# Epoch 5/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.8112 - accuracy: 0.7044WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 0.8112 - accuracy: 0.7044 - val_loss: 0.9140 - val_accuracy: 0.6283 - lr: 0.0240
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.02375.
# Epoch 6/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.6666 - accuracy: 0.7582WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.6666 - accuracy: 0.7582 - val_loss: 0.7743 - val_accuracy: 0.7138 - lr: 0.0237
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0235.
# Epoch 7/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.5674 - accuracy: 0.7934WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.5676 - accuracy: 0.7933 - val_loss: 0.7639 - val_accuracy: 0.7095 - lr: 0.0235
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.02325.
# Epoch 8/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.5082 - accuracy: 0.8162WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.5081 - accuracy: 0.8162 - val_loss: 0.7179 - val_accuracy: 0.7325 - lr: 0.0233
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.023000000000000003.
# Epoch 9/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.4585 - accuracy: 0.8357WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.4585 - accuracy: 0.8357 - val_loss: 0.6417 - val_accuracy: 0.7630 - lr: 0.0230
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.022750000000000003.
# Epoch 10/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.4166 - accuracy: 0.8503WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.4167 - accuracy: 0.8502 - val_loss: 0.6422 - val_accuracy: 0.7757 - lr: 0.0227
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.022500000000000003.
# Epoch 11/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.3863 - accuracy: 0.8594WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.3863 - accuracy: 0.8594 - val_loss: 0.6127 - val_accuracy: 0.7926 - lr: 0.0225
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.022250000000000002.
# Epoch 12/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.3626 - accuracy: 0.8687WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.3627 - accuracy: 0.8687 - val_loss: 0.6363 - val_accuracy: 0.7711 - lr: 0.0223
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.022000000000000002.
# Epoch 13/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.3420 - accuracy: 0.8762WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 0.3421 - accuracy: 0.8762 - val_loss: 0.6536 - val_accuracy: 0.7748 - lr: 0.0220
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.021750000000000002.
# Epoch 14/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.3248 - accuracy: 0.8822WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 0.3250 - accuracy: 0.8821 - val_loss: 0.6612 - val_accuracy: 0.7669 - lr: 0.0217
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.021500000000000002.
# Epoch 15/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.3090 - accuracy: 0.8879WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 0.3092 - accuracy: 0.8878 - val_loss: 0.6008 - val_accuracy: 0.7886 - lr: 0.0215
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.02125.
# Epoch 16/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.2942 - accuracy: 0.8930WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 0.2944 - accuracy: 0.8930 - val_loss: 0.6063 - val_accuracy: 0.7956 - lr: 0.0213
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.021.
# Epoch 17/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.2824 - accuracy: 0.8964WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 0.2824 - accuracy: 0.8964 - val_loss: 0.6024 - val_accuracy: 0.7917 - lr: 0.0210
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.02075.
# Epoch 18/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.2668 - accuracy: 0.9037WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.2668 - accuracy: 0.9038 - val_loss: 0.6320 - val_accuracy: 0.7953 - lr: 0.0207
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.020500000000000004.
# Epoch 19/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.2607 - accuracy: 0.9040WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.2607 - accuracy: 0.9040 - val_loss: 0.6041 - val_accuracy: 0.7983 - lr: 0.0205
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.020250000000000004.
# Epoch 20/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.2488 - accuracy: 0.9094WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 0.2488 - accuracy: 0.9093 - val_loss: 0.5789 - val_accuracy: 0.8059 - lr: 0.0203
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.020000000000000004.
# Epoch 21/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.2407 - accuracy: 0.9120WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.2407 - accuracy: 0.9120 - val_loss: 0.5897 - val_accuracy: 0.8040 - lr: 0.0200
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.019750000000000004.
# Epoch 22/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.2341 - accuracy: 0.9143WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.2342 - accuracy: 0.9143 - val_loss: 0.5812 - val_accuracy: 0.8016 - lr: 0.0198
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.019500000000000003.
# Epoch 23/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.2257 - accuracy: 0.9173WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.2257 - accuracy: 0.9172 - val_loss: 0.5659 - val_accuracy: 0.8113 - lr: 0.0195
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.019250000000000003.
# Epoch 24/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.2241 - accuracy: 0.9180WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.2240 - accuracy: 0.9180 - val_loss: 0.6249 - val_accuracy: 0.7941 - lr: 0.0192
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.019000000000000003.
# Epoch 25/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.2159 - accuracy: 0.9208WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.2158 - accuracy: 0.9209 - val_loss: 0.6216 - val_accuracy: 0.7986 - lr: 0.0190
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.018750000000000003.
# Epoch 26/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.2098 - accuracy: 0.9235WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.2099 - accuracy: 0.9235 - val_loss: 0.5728 - val_accuracy: 0.8104 - lr: 0.0188
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0185.
# Epoch 27/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.2009 - accuracy: 0.9263WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.2009 - accuracy: 0.9264 - val_loss: 0.5770 - val_accuracy: 0.8161 - lr: 0.0185
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.01825.
# Epoch 28/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1979 - accuracy: 0.9270WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1978 - accuracy: 0.9270 - val_loss: 0.5828 - val_accuracy: 0.8200 - lr: 0.0182
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.018.
# Epoch 29/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1947 - accuracy: 0.9295WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1947 - accuracy: 0.9294 - val_loss: 0.5795 - val_accuracy: 0.8128 - lr: 0.0180
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.01775.
# Epoch 30/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1898 - accuracy: 0.9309WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1899 - accuracy: 0.9309 - val_loss: 0.6330 - val_accuracy: 0.7947 - lr: 0.0178
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.017499999999999998.
# Epoch 31/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1823 - accuracy: 0.9331WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1823 - accuracy: 0.9332 - val_loss: 0.6295 - val_accuracy: 0.8022 - lr: 0.0175
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.017249999999999998.
# Epoch 32/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1818 - accuracy: 0.9333WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 0.1818 - accuracy: 0.9333 - val_loss: 0.5984 - val_accuracy: 0.8016 - lr: 0.0172
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.016999999999999998.
# Epoch 33/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1761 - accuracy: 0.9354WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 78ms/step - loss: 0.1760 - accuracy: 0.9354 - val_loss: 0.6456 - val_accuracy: 0.8107 - lr: 0.0170
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.016749999999999998.
# Epoch 34/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1736 - accuracy: 0.9368WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1736 - accuracy: 0.9369 - val_loss: 0.5795 - val_accuracy: 0.8122 - lr: 0.0168
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.016499999999999997.
# Epoch 35/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1705 - accuracy: 0.9373WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1705 - accuracy: 0.9373 - val_loss: 0.6375 - val_accuracy: 0.8056 - lr: 0.0165
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.01625.
# Epoch 36/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1665 - accuracy: 0.9391WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1665 - accuracy: 0.9391 - val_loss: 0.5836 - val_accuracy: 0.8249 - lr: 0.0162
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.016.
# Epoch 37/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1639 - accuracy: 0.9404WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1639 - accuracy: 0.9404 - val_loss: 0.6193 - val_accuracy: 0.8113 - lr: 0.0160
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.01575.
# Epoch 38/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1612 - accuracy: 0.9409WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1612 - accuracy: 0.9409 - val_loss: 0.6384 - val_accuracy: 0.8179 - lr: 0.0158
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0155.
# Epoch 39/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1561 - accuracy: 0.9424WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1561 - accuracy: 0.9424 - val_loss: 0.6245 - val_accuracy: 0.8095 - lr: 0.0155
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.01525.
# Epoch 40/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1572 - accuracy: 0.9422WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1573 - accuracy: 0.9422 - val_loss: 0.5912 - val_accuracy: 0.8188 - lr: 0.0153
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.015.
# Epoch 41/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1548 - accuracy: 0.9431WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 78ms/step - loss: 0.1547 - accuracy: 0.9431 - val_loss: 0.6328 - val_accuracy: 0.8182 - lr: 0.0150
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.014750000000000003.
# Epoch 42/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1522 - accuracy: 0.9451WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1522 - accuracy: 0.9451 - val_loss: 0.6318 - val_accuracy: 0.8122 - lr: 0.0148
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.014500000000000002.
# Epoch 43/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1479 - accuracy: 0.9462WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 78ms/step - loss: 0.1480 - accuracy: 0.9462 - val_loss: 0.5970 - val_accuracy: 0.8261 - lr: 0.0145
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.014250000000000002.
# Epoch 44/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1445 - accuracy: 0.9471WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1446 - accuracy: 0.9470 - val_loss: 0.5899 - val_accuracy: 0.8367 - lr: 0.0143
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.014000000000000002.
# Epoch 45/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1459 - accuracy: 0.9466WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1458 - accuracy: 0.9466 - val_loss: 0.6133 - val_accuracy: 0.8119 - lr: 0.0140
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.013750000000000002.
# Epoch 46/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1428 - accuracy: 0.9479WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1428 - accuracy: 0.9479 - val_loss: 0.6340 - val_accuracy: 0.8207 - lr: 0.0137
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.013500000000000002.
# Epoch 47/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1399 - accuracy: 0.9489WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 45s 78ms/step - loss: 0.1399 - accuracy: 0.9489 - val_loss: 0.6881 - val_accuracy: 0.7956 - lr: 0.0135
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.013250000000000001.
# Epoch 48/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1414 - accuracy: 0.9477WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1415 - accuracy: 0.9476 - val_loss: 0.6325 - val_accuracy: 0.8225 - lr: 0.0132
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.013000000000000001.
# Epoch 49/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1402 - accuracy: 0.9498WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1401 - accuracy: 0.9499 - val_loss: 0.6233 - val_accuracy: 0.8216 - lr: 0.0130
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.012750000000000001.
# Epoch 50/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1355 - accuracy: 0.9505WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1354 - accuracy: 0.9505 - val_loss: 0.5937 - val_accuracy: 0.8240 - lr: 0.0127
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0125.
# Epoch 51/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1347 - accuracy: 0.9502WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1347 - accuracy: 0.9502 - val_loss: 0.6121 - val_accuracy: 0.8207 - lr: 0.0125
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.01225.
# Epoch 52/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1334 - accuracy: 0.9509WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 45s 78ms/step - loss: 0.1334 - accuracy: 0.9509 - val_loss: 0.6290 - val_accuracy: 0.8234 - lr: 0.0122
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.012.
# Epoch 53/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1333 - accuracy: 0.9522WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1332 - accuracy: 0.9521 - val_loss: 0.6757 - val_accuracy: 0.8065 - lr: 0.0120
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.01175.
# Epoch 54/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1309 - accuracy: 0.9538WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 78ms/step - loss: 0.1310 - accuracy: 0.9537 - val_loss: 0.6633 - val_accuracy: 0.8155 - lr: 0.0117
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0115.
# Epoch 55/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1307 - accuracy: 0.9527WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 45s 79ms/step - loss: 0.1307 - accuracy: 0.9528 - val_loss: 0.6246 - val_accuracy: 0.8324 - lr: 0.0115
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.01125.
# Epoch 56/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1290 - accuracy: 0.9534WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1289 - accuracy: 0.9534 - val_loss: 0.6387 - val_accuracy: 0.8222 - lr: 0.0113
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.011.
# Epoch 57/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1238 - accuracy: 0.9551WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1238 - accuracy: 0.9550 - val_loss: 0.6421 - val_accuracy: 0.8155 - lr: 0.0110
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.010750000000000003.
# Epoch 58/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1239 - accuracy: 0.9547WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 45s 79ms/step - loss: 0.1239 - accuracy: 0.9546 - val_loss: 0.6130 - val_accuracy: 0.8219 - lr: 0.0108
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.010500000000000002.
# Epoch 59/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1237 - accuracy: 0.9552WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1237 - accuracy: 0.9552 - val_loss: 0.6683 - val_accuracy: 0.8191 - lr: 0.0105
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.010250000000000002.
# Epoch 60/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1252 - accuracy: 0.9549WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1252 - accuracy: 0.9549 - val_loss: 0.5634 - val_accuracy: 0.8330 - lr: 0.0103
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.010000000000000002.
# Epoch 61/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1200 - accuracy: 0.9566WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1200 - accuracy: 0.9566 - val_loss: 0.6707 - val_accuracy: 0.8219 - lr: 0.0100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.009750000000000002.
# Epoch 62/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1234 - accuracy: 0.9551WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 78ms/step - loss: 0.1233 - accuracy: 0.9551 - val_loss: 0.6515 - val_accuracy: 0.8225 - lr: 0.0098
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.009500000000000001.
# Epoch 63/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1188 - accuracy: 0.9569WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1188 - accuracy: 0.9569 - val_loss: 0.6713 - val_accuracy: 0.8204 - lr: 0.0095
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.00925.
# Epoch 64/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1198 - accuracy: 0.9563WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 78ms/step - loss: 0.1197 - accuracy: 0.9564 - val_loss: 0.6212 - val_accuracy: 0.8267 - lr: 0.0093
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.009.
# Epoch 65/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1176 - accuracy: 0.9576WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1177 - accuracy: 0.9576 - val_loss: 0.6826 - val_accuracy: 0.8119 - lr: 0.0090
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.008749999999999999.
# Epoch 66/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1190 - accuracy: 0.9569WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 78ms/step - loss: 0.1191 - accuracy: 0.9569 - val_loss: 0.6973 - val_accuracy: 0.8125 - lr: 0.0088
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.008499999999999999.
# Epoch 67/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1158 - accuracy: 0.9580WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1158 - accuracy: 0.9579 - val_loss: 0.6520 - val_accuracy: 0.8264 - lr: 0.0085
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.008249999999999999.
# Epoch 68/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1165 - accuracy: 0.9579WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1166 - accuracy: 0.9579 - val_loss: 0.6455 - val_accuracy: 0.8264 - lr: 0.0082
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.007999999999999998.
# Epoch 69/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1160 - accuracy: 0.9580WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1160 - accuracy: 0.9580 - val_loss: 0.6316 - val_accuracy: 0.8267 - lr: 0.0080
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.007750000000000002.
# Epoch 70/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1141 - accuracy: 0.9590WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1140 - accuracy: 0.9590 - val_loss: 0.6656 - val_accuracy: 0.8255 - lr: 0.0077
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0075000000000000015.
# Epoch 71/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1126 - accuracy: 0.9588WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1126 - accuracy: 0.9588 - val_loss: 0.6900 - val_accuracy: 0.8164 - lr: 0.0075
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.007250000000000001.
# Epoch 72/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1120 - accuracy: 0.9598WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1120 - accuracy: 0.9598 - val_loss: 0.6220 - val_accuracy: 0.8240 - lr: 0.0072
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.007000000000000001.
# Epoch 73/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1094 - accuracy: 0.9605 ETA: 0s - loss: 0.1095 - accuracy: 0.WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 46s 81ms/step - loss: 0.1094 - accuracy: 0.9605 - val_loss: 0.6807 - val_accuracy: 0.8246 - lr: 0.0070
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.006750000000000001.
# Epoch 74/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1143 - accuracy: 0.9588WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 51s 90ms/step - loss: 0.1143 - accuracy: 0.9588 - val_loss: 0.6861 - val_accuracy: 0.8264 - lr: 0.0068
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.006500000000000001.
# Epoch 75/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1114 - accuracy: 0.9595WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 51s 90ms/step - loss: 0.1114 - accuracy: 0.9595 - val_loss: 0.6573 - val_accuracy: 0.8258 - lr: 0.0065
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.00625.
# Epoch 76/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1107 - accuracy: 0.9594WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 51s 90ms/step - loss: 0.1106 - accuracy: 0.9595 - val_loss: 0.6534 - val_accuracy: 0.8270 - lr: 0.0063
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.006.
# Epoch 77/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1099 - accuracy: 0.9594WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 51s 89ms/step - loss: 0.1100 - accuracy: 0.9594 - val_loss: 0.6470 - val_accuracy: 0.8282 - lr: 0.0060
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.00575.
# Epoch 78/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1091 - accuracy: 0.9608WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 51s 89ms/step - loss: 0.1091 - accuracy: 0.9608 - val_loss: 0.6463 - val_accuracy: 0.8303 - lr: 0.0058
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0055.
# Epoch 79/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1082 - accuracy: 0.9611WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 51s 90ms/step - loss: 0.1082 - accuracy: 0.9610 - val_loss: 0.6651 - val_accuracy: 0.8179 - lr: 0.0055
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0052499999999999995.
# Epoch 80/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1082 - accuracy: 0.9604WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 51s 89ms/step - loss: 0.1082 - accuracy: 0.9605 - val_loss: 0.6502 - val_accuracy: 0.8231 - lr: 0.0052
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.004999999999999999.
# Epoch 81/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1079 - accuracy: 0.9612WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 52s 90ms/step - loss: 0.1079 - accuracy: 0.9612 - val_loss: 0.6533 - val_accuracy: 0.8210 - lr: 0.0050
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.004749999999999999.
# Epoch 82/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1067 - accuracy: 0.9608WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 51s 89ms/step - loss: 0.1067 - accuracy: 0.9608 - val_loss: 0.6531 - val_accuracy: 0.8309 - lr: 0.0047
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.004500000000000001.
# Epoch 83/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1091 - accuracy: 0.9606WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 51s 89ms/step - loss: 0.1091 - accuracy: 0.9606 - val_loss: 0.6715 - val_accuracy: 0.8297 - lr: 0.0045
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.004250000000000001.
# Epoch 84/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1057 - accuracy: 0.9621WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 50s 88ms/step - loss: 0.1056 - accuracy: 0.9621 - val_loss: 0.6877 - val_accuracy: 0.8194 - lr: 0.0043
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.004000000000000001.
# Epoch 85/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1049 - accuracy: 0.9623WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 47s 83ms/step - loss: 0.1049 - accuracy: 0.9623 - val_loss: 0.6360 - val_accuracy: 0.8306 - lr: 0.0040
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.0037500000000000007.
# Epoch 86/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1065 - accuracy: 0.9616WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 43s 75ms/step - loss: 0.1065 - accuracy: 0.9616 - val_loss: 0.6640 - val_accuracy: 0.8240 - lr: 0.0037
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.0035000000000000005.
# Epoch 87/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1057 - accuracy: 0.9617WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 43s 76ms/step - loss: 0.1057 - accuracy: 0.9617 - val_loss: 0.6711 - val_accuracy: 0.8294 - lr: 0.0035
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.0032500000000000003.
# Epoch 88/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1070 - accuracy: 0.9615WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 43s 76ms/step - loss: 0.1070 - accuracy: 0.9615 - val_loss: 0.6467 - val_accuracy: 0.8315 - lr: 0.0033
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.003.
# Epoch 89/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1047 - accuracy: 0.9628WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 43s 76ms/step - loss: 0.1046 - accuracy: 0.9629 - val_loss: 0.6401 - val_accuracy: 0.8306 - lr: 0.0030
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.00275.
# Epoch 90/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1054 - accuracy: 0.9621WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 0.1054 - accuracy: 0.9621 - val_loss: 0.6310 - val_accuracy: 0.8339 - lr: 0.0027
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.0024999999999999996.
# Epoch 91/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1042 - accuracy: 0.9625WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 0.1041 - accuracy: 0.9625 - val_loss: 0.6397 - val_accuracy: 0.8339 - lr: 0.0025
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.0022499999999999994.
# Epoch 92/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1040 - accuracy: 0.9633WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1040 - accuracy: 0.9633 - val_loss: 0.6928 - val_accuracy: 0.8273 - lr: 0.0022
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.001999999999999999.
# Epoch 93/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1052 - accuracy: 0.9620WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 43s 76ms/step - loss: 0.1053 - accuracy: 0.9619 - val_loss: 0.6364 - val_accuracy: 0.8357 - lr: 0.0020
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.001749999999999999.
# Epoch 94/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1049 - accuracy: 0.9620WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 0.1050 - accuracy: 0.9620 - val_loss: 0.6710 - val_accuracy: 0.8255 - lr: 0.0018
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.0015000000000000013.
# Epoch 95/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1044 - accuracy: 0.9616WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 43s 76ms/step - loss: 0.1044 - accuracy: 0.9616 - val_loss: 0.6329 - val_accuracy: 0.8342 - lr: 0.0015
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.0012500000000000011.
# Epoch 96/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1048 - accuracy: 0.9624WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 0.1047 - accuracy: 0.9624 - val_loss: 0.6708 - val_accuracy: 0.8288 - lr: 0.0012
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.0010000000000000009.
# Epoch 97/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1039 - accuracy: 0.9628WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 76ms/step - loss: 0.1038 - accuracy: 0.9628 - val_loss: 0.6515 - val_accuracy: 0.8288 - lr: 0.0010
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.0007500000000000007.
# Epoch 98/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1030 - accuracy: 0.9628WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 43s 76ms/step - loss: 0.1031 - accuracy: 0.9628 - val_loss: 0.6729 - val_accuracy: 0.8255 - lr: 7.5000e-04
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.0005000000000000004.
# Epoch 99/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1038 - accuracy: 0.9630WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 44s 77ms/step - loss: 0.1037 - accuracy: 0.9630 - val_loss: 0.6500 - val_accuracy: 0.8279 - lr: 5.0000e-04
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 0.0002500000000000002.
# Epoch 100/100
# 571/571 [============================>.] - ETA: 0s - loss: 0.1023 - accuracy: 0.9623WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 572/571 [==============================] - 45s 79ms/step - loss: 0.1024 - accuracy: 0.9623 - val_loss: 0.6666 - val_accuracy: 0.8231 - lr: 2.5000e-04

# %%
print("df")
# Out:
# df
